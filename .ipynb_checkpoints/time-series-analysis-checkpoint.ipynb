# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from astropy.io import ascii

# %%
df_data1431181 = ascii.read("datasets/time-curves/1431181/kplr001431181-2009259160929_llc_lc.tbl").to_pandas()

# %%
for filename in os.listdir('datasets/time-curves/1431181/'):
    if(filename.endswith('.tbl') and not filename.endswith('2009259160929_llc_lc.tbl')):        
        data = ascii.read('datasets/time-curves/1431181/' + filename).to_pandas()        
        df_data1431181 = df_data1431181.append(data)

# %%
df_data1431181.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67663 entries, 0 to 1555
# Data columns (total 21 columns):
# TIME               64749 non-null float64
# TIME_BJD           64749 non-null float64
# TIMECORR           67663 non-null float64
# CADENCENO          67663 non-null float64
# SAP_FLUX           63810 non-null float64
# SAP_FLUX_ERR       63810 non-null float64
# SAP_BKG            63810 non-null float64
# SAP_BKG_ERR        63810 non-null float64
# PDCSAP_FLUX        63171 non-null float64
# PDCSAP_FLUX_ERR    63171 non-null float64
# SAP_QUALITY        67663 non-null float64
# PSF_CENTR1         0 non-null float64
# PSF_CENTR1_ERR     0 non-null float64
# PSF_CENTR2         0 non-null float64
# PSF_CENTR2_ERR     0 non-null float64
# MOM_CENTR1         63810 non-null float64
# MOM_CENTR1_ERR     63810 non-null float64
# MOM_CENTR2         63810 non-null float64
# MOM_CENTR2_ERR     63810 non-null float64
# POS_CORR1          64022 non-null float64
# ...

# %%
df_time_flux = df_data1431181[['TIME','PDCSAP_FLUX']].dropna()

# %%
sns.set()

# %%
plt.figure(1,dpi=1000)
sns.lineplot(df_time_flux['TIME'],df_time_flux['PDCSAP_FLUX'])
plt.xlabel('Time')
plt.ylabel('Flux')
plt.title("1431181")
plt.show()

# %%
df_data = ascii.read("datasets/time-curves/1431181/kplr001431181-2009259160929_llc_lc.tbl").to_pandas()[['TIME','PDCSAP_FLUX']].dropna()

# %%
plt.figure(1,dpi=300)
sns.lineplot(df_data['TIME'],df_data['PDCSAP_FLUX'])

# %%
df_reduced = df_data.loc[df_data.TIME <= 173]

# %%
plt.figure(1,dpi=300)
sns.lineplot(df_reduced.TIME,df_reduced.PDCSAP_FLUX)

# %%
df_reduced = df_data.loc[df_data.TIME <= 171]
plt.figure(1,dpi=300)
sns.lineplot(df_reduced.TIME,df_reduced.PDCSAP_FLUX)

# %%
df_data1431567 = ascii.read("datasets/time-curves/1431567/kplr001431567-2009166043257_llc_lc.tbl").to_pandas()

# %%
for filename in os.listdir('datasets/time-curves/1431567/'):
    if(filename.endswith('.tbl') and not filename.endswith('2009166043257_llc_lc.tbl')):        
        data = ascii.read('datasets/time-curves/1431567/' + filename).to_pandas()        
        df_data1431567 = df_data1431567.append(data)

# %%
df_time_flux1431567 = df_data1431567[['TIME','PDCSAP_FLUX']].dropna()

# %%
plt.figure(1,dpi=1000)
sns.lineplot(df_time_flux1431567['TIME'],df_time_flux1431567['PDCSAP_FLUX'])
plt.xlabel('Time')
plt.ylabel('Flux')
plt.title("1431567")
plt.show()

# %%
df_data1431705 = ascii.read("datasets/time-curves/1431705/kplr001431705-2009166043257_llc_lc.tbl").to_pandas()

# %%
for filename in os.listdir('datasets/time-curves/1431567/'):
    if(filename.endswith('.tbl') and not filename.endswith('2009166043257_llc_lc.tbl')):        
        data = ascii.read('datasets/time-curves/1431567/' + filename).to_pandas()        
        df_data1431567 = df_data1431567.append(data)

# %%
df_time_flux1431567 = df_data1431567[['TIME','PDCSAP_FLUX']].dropna()

plt.figure(1,dpi=1000)
sns.lineplot(df_time_flux1431567['TIME'],df_time_flux1431567['PDCSAP_FLUX'])
plt.xlabel('Time')
plt.ylabel('Flux')
plt.title("1431567")
plt.show()
